# %% [markdown]
# <a href="https://colab.research.google.com/github/Millimono/DEEP-LERANING/blob/main/pfe_pretraitement_cadrage_ROI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -u "/content/sample_data/totalDVD10.zip" -d "/content/sample_data/"
# Out:
# Archive:  /content/sample_data/totalDVD10.zip
#    creating: /content/sample_data/totalDVD10/
#   inflating: /content/sample_data/totalDVD10/0051.jpg
#   inflating: /content/sample_data/totalDVD10/0053.jpg
#   inflating: /content/sample_data/totalDVD10/0055.jpg
#   inflating: /content/sample_data/totalDVD10/0057.jpg
#   inflating: /content/sample_data/totalDVD10/0127.jpg
#   inflating: /content/sample_data/totalDVD10/0130.jpg
#   inflating: /content/sample_data/totalDVD10/0136.jpg
#   inflating: /content/sample_data/totalDVD10/0138.jpg
#   inflating: /content/sample_data/totalDVD10/0139.jpg
#   inflating: /content/sample_data/totalDVD10/0160.jpg
#   inflating: /content/sample_data/totalDVD10/0161.jpg
#   inflating: /content/sample_data/totalDVD10/0162.jpg
#   inflating: /content/sample_data/totalDVD10/0163.jpg
#   inflating: /content/sample_data/totalDVD10/0164.jpg
#   inflating: /content/sample_data/totalDVD10/0165.jpg

# %%
import numpy as np
#import pydicom
import os
import matplotlib.pyplot as plt
from glob import glob
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.ndimage
from skimage import morphology
from skimage import measure
from skimage.transform import resize
from sklearn.cluster import KMeans
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.tools import FigureFactory as FF
from plotly.graph_objs import *

# %%
import cv2

# %%
data_path = '/content/sample_data/totalDVD10'
output_path = working_path ='/content/sample_data/totalDVD10_output'
g = glob(data_path + '/*.jpg')

# %%
# Print out the first 5 file names to verify we're in the right folder.
print ("Total of %d  images.\nFirst 5 filenames:" % len(g))
print( '\n'.join(g[:5]) )
# Out:
# Total of 15  images.
# First 5 filenames:
# /content/sample_data/totalDVD10/0051.jpg
# /content/sample_data/totalDVD10/0136.jpg
# /content/sample_data/totalDVD10/0127.jpg
# /content/sample_data/totalDVD10/0161.jpg
# /content/sample_data/totalDVD10/0165.jpg

# %%
import cv2
from matplotlib import pyplot
import numpy as np

# %%
import glob
cv_img = []
for img in glob.glob("/content/sample_data/totalDVD10/*.jpg"):
    n= cv2.imread(img,0)
    cv_img.append(n)

# %%
cv_img[2].shape
# Out:
# (512, 512)

# %%
len(cv_img)
# Out:
# 15

# %%
pyplot.imshow(cv_img[5],'gray');
pyplot.xlabel("image")
pyplot.show();

# %%
# Calcule l'histogramme de l'image
img_exemple=cv_img[5]
hist = cv2.calcHist([img_exemple], [0], None, [256], [0, 256])
pyplot.plot(hist)
pyplot.show();

# %% [markdown]
# # Egliser Les images

# %% [markdown]
# **Une seule image en guise d'exemple**

# %%
#egalisation d'une image 
#img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img1 = cv2.equalizeHist(img_exemple)
img_exemple=img1
pyplot.imshow(img_exemple,'gray');
pyplot.xlabel("image egalisée ")
pyplot.show();

# %% [markdown]
# **plusieurs Images**

# %%
import glob
img_egal = []
for img in cv_img :
    n = cv2.equalizeHist(img)
    img_egal.append(n)
len(img_egal)
# Out:
# 202

# %%
pyplot.imshow(img_egal[5],'gray');
pyplot.xlabel("image egalisée ")
pyplot.show();

# %% [markdown]
# # Binarisation ou Seuillage

# %% [markdown]
# **Pour Une Seule Image**

# %% [markdown]
# **Methode OTSU**

# %%
ret2,newImg2 = cv2.threshold(cv_img[5] ,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
pyplot.imshow(newImg2,'gray');
pyplot.xlabel("Après seuillage")
pyplot.show();

# %%
(retVal, newImg) = cv2.threshold(cv_img[5], 156, 255, cv2.THRESH_BINARY)
pyplot.imshow(newImg,'gray');
pyplot.xlabel("Après seuillage")
pyplot.show();

# %% [markdown]
# **Pour Plusieurs Images**

# %%
import glob
img_Binar = []
for img in cv_img :
    #(retVal, n) = cv2.threshold(img, 156, 255, cv2.THRESH_BINARY)
    (retVal,n) = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    img_Binar.append(n)
len(img_Binar)
# Out:
# 15

# %%
pyplot.imshow(img_Binar[5],'gray');
pyplot.xlabel("image seuillage ")
pyplot.show();

# %% [markdown]
# # Remplissage De L'arrière Plan

# %% [markdown]
# **Une Seule Image**

# %%
img=newImg
h, w= img.shape

# create zeros mask 2 pixels larger in each dimension
mask = np.zeros([h + 2, w + 2], np.uint8)

# do floodfill
result2 = img.copy()
cv2.floodFill(result2, mask, (0,0), (255,255,255), flags=8)
#cv2.floodFill(result2, mask, (38,313), (255,255,255), (3,151,65), (3,151,65), flags=8)
#cv2.floodFill(result2, mask, (363,345), (255,255,255), (3,151,65), (3,151,65), flags=8)

# write result to disk
#cv2.imwrite("soccer_floodfill.jpg", result)

# display it
pyplot.imshow(result2, 'gray');
pyplot.xlabel("Après Remplissage de la zone en arrière plan")
pyplot.show();
newImg.shape
# Out:
# (512, 512)

# %% [markdown]
# **Plusieurs Images**

# %%
import glob
img_Arr_p =[]
for img in img_Binar :
    (retVal,n) = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    h, w= img.shape
    # create zeros mask 2 pixels larger in each dimension
    mask = np.zeros([h + 2, w + 2], np.uint8)
    # do floodfill
    n = img.copy()
    cv2.floodFill(n, mask, (0,0), (255,255,255), flags=8)
    img_Arr_p.append(n)

# %%
pyplot.imshow(img_Arr_p[5],'gray');
pyplot.xlabel("image img_Arr_p ")
pyplot.show();

# %% [markdown]
# # Renverser La couleur

# %% [markdown]
# **Pour Une Seule Image**

# %%
def Vice(pic, name):
    pic = (255 - pic)

    pyplot.imshow(pic, 'gray');
    pyplot.xlabel("Après Remplissage de la zone en arrière plan")
    pyplot.show();
Vice(result2, 'test1.png')

# %%
g=cv2.bitwise_not(result2) 

pyplot.imshow(g, 'gray');
pyplot.xlabel("Après Remplissage de la zone en arrière plan")
pyplot.show();
newImg.shape
# Out:
# (512, 512)

# %% [markdown]
# **Pour Plusieurs Images**

# %%
import glob
img_Coul_In =[]
for img in img_Arr_p :
    n = cv2.bitwise_not(img)
    img_Coul_In.append(n)

# %%
pyplot.imshow(img_Coul_In[5],'gray');
pyplot.xlabel("image f ")
pyplot.show();

# %% [markdown]
# # ENCADRER LE ROI

# %% [markdown]
# **Pour Une Seule Image**

# %%
image=cv_img[5]
image_copy = image.copy()

x,y,w,h = cv2.boundingRect(g)
cv2.rectangle(image_copy,(x,y),(x+w,y+h),(0,255,0),2)

pyplot.imshow(image_copy, 'gray');
pyplot.xlabel("Après Remplissage de la zone en arrière plan")
pyplot.show();

# %%
img_decoupe = image_copy[y:y+h,x:x+w]
pyplot.imshow(img_decoupe, 'gray');
pyplot.xlabel("Après Remplissage de la zone en arrière plan")
pyplot.show();

# %% [markdown]
# **Pour Plusieurs Images**

# %%
import glob
x,y,w,h
img_Encadre =[]

for img in img_Coul_In :
    x,y,w,h = cv2.boundingRect(img)

for img2 in cv_img :
    cv2.rectangle(img2,(x,y),(x+w,y+h),(0,255,0),2)
    img_decoupe = img2[y:y+h,x:x+w]
    img_Encadre.append(img_decoupe)

# %%
pyplot.imshow(img_Encadre[5], 'gray');
pyplot.xlabel("Après Remplissage de la zone en arrière plan")
pyplot.show();

# %% [markdown]
# # Enregistrement

# %%
import os
import imageio

Input_Folder = '/content/sample_data/totalDVD10'
Output_Folder = '/content/sample_data/totalDVD10_output'
Input_Image_List = os.listdir(Input_Folder)
i=0
for img in img_Encadre :
        cv2.imwrite(Output_Folder + '/' + 'dvd10'+str(i) + '.jpg', img)
        i=i+1
        #cv2.imwrite('myImage.png', img)
        #imageio.imwrite('pic.png', x[157])

# %%
int(223.9)
